# %% [markdown]
# ###  Number is Positive,Negative, Zero

# %%
num =  int(input("enter the number:"))
if num > 0 :
    print(f"{num} is a Postive number")
elif num < 0:
    print(f"{num} is a Negative number")
else:
    print(f"{num} It's a Zero")
# Out:
# enter the number: 0
# 0 It's a Zero
